# %%
# 1. Write a program to print your name.
a="Sharmila Shaik"
print(a)
#or
# name=input("enter my name:")
# print(name)


# 2. Write a program for a Single line comment and multi-line comments
# This is a single-line comment
print("Single-line comments start with # and using # only that single line will not be executed in entire program")

"""
This is a multi-line comment 
It is written using triple quotes
It can span multiple lines
"""
print("Multi-line comments start and end with 3 commas.....by using those at once we can stop those number of lines without executing")


# 3. Define variables for different Data Types int, Boolean, char, float, double and print on the Console
a=5
print("integer value:",a,"and datatype of c is:",type(a))

b=True
print("boolean value:",b,"and datatype of c is:",type(b))

c=5.6
print("float value:",c, "and datatype of c is:",type(c))

char="sharmila"[0]
print(char)
#or
cha=input("enter a charater:")
if len(cha)==1:
    print("valid",cha)
else:
    print("enter valid character")

double=11.345679876
print(double)
  
# 4. Define the local and Global variables with the same name and print both variables and understand the scope of the variables
x=10
def display():
    x = 20          # Local variable with same name executes only inside function
    print("Inside function (local x):", x)
display()
print("Outside function (global x):", x)      #Global variable accessible everywhere
#Both global and local have the same name, but Python treats them separately
#we are giving x value first outside the function and again we changed value inside the function that got updated
#even though it updates the value before updation value also we can see in output by using global variable
# Out:
# Sharmila Shaik
# Single-line comments start with # and using # only that single line will not be executed in entire program
# Multi-line comments start and end with 3 commas.....by using those at once we can stop those number of lines without executing
# integer value: 5 and datatype of c is: <class 'int'>
# boolean value: True and datatype of c is: <class 'bool'>
# float value: 5.6 and datatype of c is: <class 'float'>
# s
# enter a charater: d
# valid d
# 11.345679876
# Inside function (local x): 20
# Outside function (global x): 10
